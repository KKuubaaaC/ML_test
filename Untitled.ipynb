# %%
# %pip install --upgrade scikit-learn==0.23.0
# Out:
# ...
#      ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#      ---------------------------------------- 0.1/7.2 MB 1.1 MB/s eta 0:00:07
#       --------------------------------------- 0.1/7.2 MB 1.2 MB/s eta 0:00:06
#      - -------------------------------------- 0.3/7.2 MB 1.8 MB/s eta 0:00:04
#      -- ------------------------------------- 0.4/7.2 MB 2.1 MB/s eta 0:00:04
#      -- ------------------------------------- 0.5/7.2 MB 2.2 MB/s eta 0:00:04
#      ---- ----------------------------------- 0.9/7.2 MB 3.2 MB/s eta 0:00:02
#      ----- ---------------------------------- 1.0/7.2 MB 3.5 MB/s eta 0:00:02
#      ---------- ----------------------------- 2.0/7.2 MB 5.4 MB/s eta 0:00:01
#      ----------- ---------------------------- 2.1/7.2 MB 5.5 MB/s eta 0:00:01
#      ------------- -------------------------- 2.5/7.2 MB 5.3 MB/s eta 0:00:01
#      ----------------- ---------------------- 3.1/7.2 MB 6.3 MB/s eta 0:00:01
# ...

# %%
print(1)
# Out:
# 1

# %%
import numpy as np
import pandas as pd
import matplotlib as plt
